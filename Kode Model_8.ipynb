# %%
# Instal library
# %pip install mlxtend
import pandas as pd
import pickle
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
# Out:
# Requirement already satisfied: mlxtend in c:\users\republic of gamers\anaconda3\lib\site-packages (0.23.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: joblib>=0.13.2 in c:\users\republic of gamers\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\republic of gamers\anaconda3\lib\site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\republic of gamers\anaconda3\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\republic of gamers\anaconda3\lib\site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\republic of gamers\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\republic of gamers\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\republic of gamers\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\republic of gamers\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\republic of gamers\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\republic of gamers\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\republic of gamers\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\republic of gamers\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\republic of gamers\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\republic of gamers\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\republic of gamers\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\republic of gamers\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)

# %%
# Load dataset dari file Excel
data = pd.read_excel("C:\\Users\\Republic Of Gamers\\Downloads\\BulanMei2022.xlsx")

# %%
# Preprocessing data
# Mengubah atribut yang dibutuhkan (order no, item name, qty) menjadi format transaksi
transactions = data.groupby('order no').apply(lambda x: list(x['item name'])).tolist()

# %%
# Encode transaksi menggunakan TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Langkah 4: Pemodelan
# Penerapan algoritma FP-Growth untuk mendapatkan frequent itemsets
frequent_itemsets = fpgrowth(df_encoded, min_support=0.01, use_colnames=True)

# %%
# Sortir frequent itemsets berdasarkan support
frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)

# %%
# Membuat FP-Tree berdasarkan frequent itemsets
fp_tree = {}
for index, row in frequent_itemsets.iterrows():
    current_node = fp_tree
    for item in row['itemsets']:
        if item not in current_node:
            current_node[item] = {'count': row['support'], 'children': {}}
        else:
            current_node[item]['count'] += row['support']
        current_node = current_node[item]['children']

# %%
# Fungsi untuk pembangkitan Conditional Pattern Base
def generate_conditional_pattern_base(tree, prefix):
    conditional_pattern_base = {}

    for item, node in tree.items():
        new_prefix = prefix.copy()
        new_prefix.append(item)
        support = node['count']

        # Tambahkan ke conditional pattern base
        conditional_pattern_base[tuple(new_prefix)] = support

        # Rekursif untuk anak-anak node
        conditional_pattern_base.update(generate_conditional_pattern_base(node['children'], new_prefix))

    return conditional_pattern_base

# %%
# Menggunakan FP-Tree untuk pembangkitan Conditional Pattern Base
prefix_example = []
conditional_pattern_base_result = generate_conditional_pattern_base(fp_tree, prefix_example)

# %%
# Tampilan hasil
print("4. Pembangkitan Conditional Pattern Base:")
for pattern, support in conditional_pattern_base_result.items():
    print(f"{pattern}: {support}")
# Out:
# 4. Pembangkitan Conditional Pattern Base:
# ('Medan Jaya 2000',): 0.0949845895208742
# ('Kerupuk Putih Jaring 2.000',): 0.10927430652843934
# ('Kerupuk Putih Jaring 2.000', 'Medan Jaya 2000'): 0.017091622303166153
# ('Roti Ikan Hiu Kacang',): 0.130568786775007
# ('Roti Ikan Hiu Kacang', 'Medan Jaya 2000'): 0.017371812832726253
# ('Roti Ikan Hiu Kacang', 'Kerupuk Putih Jaring 2.000'): 0.012608573830204538
# ('Roti Ikan Hiu Kacang', 'Pok-Pok Chicken'): 0.011768002241524236
# ('Kerupuk Kuning',): 0.13617259736620901
# ('Kerupuk Kuning', 'Kerupuk Putih Jaring 2.000'): 0.022135051835247967
# ('Kerupuk Kuning', 'Medan Jaya 2000'): 0.014569907537125245
# ('Kerupuk Kuning', 'Kerupuk Kulit'): 0.010647240123283833
# ('Pok-Pok Chicken',): 0.09106192210703279
# ('Pok-Pok Chicken', 'Medan Jaya 2000'): 0.017932193891846457
# ('Nabati Wafer Coklat 46 gr',): 0.11403754553096104
# ('Nabati Wafer Coklat 46 gr', 'Nabati Wafer Keju 46 gr'): 0.016531241244045952
# ('Nabati Wafer Coklat 46 gr', 'Roti Ikan Hiu Kacang'): 0.015690669655365648
# ('Nabati Wafer Coklat 46 gr', 'Medan Jaya 2000'): 0.015690669655365648
# ('HoHo Rasa Balado',): 0.08069487251330905
# ('HoHo Rasa Balado', 'Medan Jaya 2000'): 0.01288876435976464
# ('HoHo Rasa Balado', 'Pok-Pok Chicken'): 0.011207621182404036
# ('Nabati Wafer Keju 46 gr',): 0.0658447744466237
# ('Nabati Wafer Keju 46 gr', 'Medan Jaya 2000'): 0.01316895488932474
# ('Lotte Choco Pie Coklat',): 0.04819277108433735
# ('Tricks Kimci',): 0.06052115438498178
# ('Tricks Kimci', 'Tricks Rendang'): 0.013449145418884841
# ('Teh Botol Sosro 350ml',): 0.04286915102269543
# ('AICE Chocolate Crispy',): 0.04230876996357523
# ('Opak Padang',): 0.04230876996357523
# ('Tricks Rendang',): 0.04202857943401513
# ('Jetz Stick Choco Fiesta',): 0.040347436256654524
# ('Beng Beng Reguler 20gr',): 0.04006724572709443
# ('Kerupuk Tahu',): 0.03950686466797422
# ('Roma Better vanilla 22gr',): 0.039226674138414123
# ('Pucuk Harum 350ml',): 0.03894648360885402
# ('Superstar Triple Chocolate 18 gr',): 0.03894648360885402
# ('Fullo Blasto',): 0.03670495937237321
# ("Toretto's Potato Stick Balado 30gr",): 0.03614457831325301
# ('Kerupuk Kulit',): 0.035864387783692914
# ('Nextar Brownies',): 0.034743625665452506
# ('Aneka Roti 2.500',): 0.03446343513589241
# ('Borobudur 1000',): 0.033622863547212105
# ('Toyaki Rasa Ayam Bawang 20gr',): 0.033622863547212105
# ('Bakso Udang Bakar',): 0.032502101428971704
# ('AICE Mochie Coklat',): 0.0316615298402914
# ('AICE Taro Crispy',): 0.030540767722050995
# ('Teh botol Sosro Kotak',): 0.030540767722050995
# ('Yakult',): 0.030260577192490895
# ('Choki Choki Cashew Doraemon 10gr',): 0.02942000560381059
# ('AICE Mochie Klepon',): 0.02913981507425049
# ('Strawbeeri Crispy',): 0.02913981507425049
# ('Chitato Lite NOS Renceng',): 0.02885962454469039
# ('Nabati Siip chocolate',): 0.02885962454469039
# ('Kraft Keju Cake 16gr',): 0.02885962454469039
# ('Chiki Twist 22.5 gr',): 0.028299243485570186
# ('Vegetable Cheese Stick',): 0.027458671896889886
# ('Nabati Siip Corn',): 0.027178481367329786
# ('Tricks Original',): 0.04847296161389745
# ('Tricks Original', 'Tricks Rendang'): 0.011487811711964136
# ('Tricks Original', 'Tricks Kimci'): 0.010367049593723731
# ('AICE Mochie vanilla',): 0.02633790977864948
# ('Pisang Saleh',): 0.02549733818996918
# ('Toyaki Rasa BBQ',): 0.02549733818996918
# ('AICE Coffe Crispy',): 0.025217147660409077
# ('Baricho Chocolate Flavour 500',): 0.024656766601288876
# ('AICE Mochie Durian',): 0.023816195012608572
# ('Kerupuk Ubi 1.000',): 0.023536004483048472
# ('Good Time Chocochips Cookies',): 0.023536004483048472
# ('Garuda Atom Manis',): 0.023255813953488372
# ('Toyaki Rasa Jagung Bakar',): 0.02241524236480807
# ('Fruit tea Blackcurrent 350 ml',): 0.022135051835247967
# ('Toyaki Rasa Rumput Laut 20gr',): 0.022135051835247967
# ('Chocolate MAX Cone Corong',): 0.021854861305687867
# ('Oreo Chocolate Roll 133gr',): 0.021854861305687867
# ('Nabati Siip Keju',): 0.021574670776127767
# ('Bear Brand STM',): 0.021574670776127767
# ('Chitato Sapi Panggang',): 0.021294480246567667
# ('Timtam Maxi Vanilla 16gr',): 0.021294480246567667
# ('Gery Snack Cereal',): 0.021014289717007566
# ('Lotte Choco Pie Cheese',): 0.021014289717007566
# ('Roma Sari Gandum 2000',): 0.020734099187447463
# ('Astor Double Chocolate 40gr',): 0.020453908657887362
# ('Permen Karet 500 (1)',): 0.020173718128327262
# ('AICE 2 Colors Stick',): 0.020173718128327262
# ('Kerupuk Ubi Original Besar',): 0.019893527598767162
# ('AICE Sundae Strawberry',): 0.019613337069207062
# ('Oreo Softcake 16gr',): 0.019613337069207062
# ('Lotte Toppo Vanilla Chocolate',): 0.019613337069207062
# ('Tisu Sedang TESSA',): 0.01933314653964696
# ('Roma Arden Chocosplendid 30gr',): 0.018772765480526758
# ('Buavita Guava 250ml',): 0.018492574950966657
# ('Berry Choco MAX Strawberry',): 0.018492574950966657
# ('Garuda Rosta Rasa Pedas',): 0.017932193891846457
# ('Biskuat Bolu Coklat 6gr',): 0.017652003362286353
# ('Black Pandan',): 0.017371812832726253
# ('Fruit Tea Freeze Botol',): 0.017091622303166153
# ('Sweet Corn Stick',): 0.017091622303166153
# ('Oreo C/S/C Vanilla 133gr',): 0.016531241244045952
# ('Roma Malkist 2 Rasa Coklat dan Kelapa',): 0.016251050714485852
# ('Astor Singles 18gr',): 0.016251050714485852
# ('Black Chocolate',): 0.015970860184925748
# ('Kopiko 78C Coffee Latte 240ml',): 0.015970860184925748
# ('Gery Saluut Malkist Coklat Kelapa',): 0.015410479125805548
# ('Floridina Orange Botol 350ml',): 0.015410479125805548
# ('Oops Baked Chicken Tomato',): 0.015410479125805548
# ('Toyaki Rasa Bawang Pedas 20gr',): 0.015410479125805548
# ('Fruit tea Apel Botol',): 0.015410479125805548
# ('Sundae Coklat',): 0.015410479125805548
# ('Nextar Nastar',): 0.015130288596245448
# ('Choki Choki Stik 27gr',): 0.014850098066685346
# ('Permen Blaster Pop Hanger Manggo',): 0.014850098066685346
# ('Oreo Lup2000 Original 38gr',): 0.014850098066685346
# ('Wafer Tanggo Royal  Coklat 120 gr',): 0.014850098066685346
# ('Fruit Tea Blackcurrant Kotak',): 0.014289717007565145
# ('Roma Slai O Lai Strawberry 24gr',): 0.014009526478005043
# ('Permen Blaster Pop Hanger Grape',): 0.013729335948444943
# ('Kalpa 24gr',): 0.013449145418884841
# ('Oreo Lup2000 Ice Cream (Blueberry)',): 0.01316895488932474
# ('Canon Ball',): 0.01316895488932474
# ('Oops Roasted Sweet Corn',): 0.01316895488932474
# ('Hansaplast',): 0.01316895488932474
# ('Sabun Cream Ekonomi',): 0.012608573830204538
# ('Permen Blaster Pop Hanger Orange',): 0.012608573830204538
# ('Black Strawberry',): 0.012608573830204538
# ('White Koffie Renceng',): 0.012608573830204538
# ('Buavita Apel 250ml',): 0.012048192771084338
# ('Tanggo Wafer Royal Coklat 47 gr',): 0.012048192771084338
# ('Tanggo Wafer Vanilla Milk 47 gr',): 0.012048192771084338
# ('Roma Slai O Lai Blueberry 32gr',): 0.012048192771084338
# ('Buavita Mangga 250ml',): 0.012048192771084338
# ('Fruit tea Strawberry Botol',): 0.011768002241524236
# ('Hemaviton Jeruk',): 0.011487811711964136
# ('Toracafe Cappucino LJ 180ml',): 0.011487811711964136
# ('Permen Tamarin 500 (2)',): 0.011207621182404036
# ('Garuda Rosta Rasa Bawang',): 0.010927430652843934
# ('Hemaviton Less Sugar',): 0.010927430652843934
# ('Permen Kis 500 (2)',): 0.010927430652843934
# ('Roma Slai O Lai Strawberry Roll',): 0.010647240123283833
# ('Roma Slai O Lai Blueberry Roll 128Gram',): 0.010367049593723731
# ('Kerupuk Udang 3.000',): 0.010086859064163631
# ('Kopi Luwak White Ori Botol',): 0.010086859064163631
# ('Dark Coklat',): 0.010086859064163631

# %%
# Fungsi untuk pembangkitan Conditional FP-tree
def build_conditional_fp_tree(conditional_pattern_base):
    conditional_fp_tree = {}

    for pattern, support in conditional_pattern_base.items():
        current_node = conditional_fp_tree

        for item in pattern:
            if item not in current_node:
                current_node[item] = {'count': support, 'parent': None, 'children': {}}
            else:
                current_node[item]['count'] += support

            if 'parent' in current_node[item]:
                current_node[item]['parent'] = current_node

            current_node = current_node[item]['children']

    return conditional_fp_tree

# %%
# Menggunakan Conditional Pattern Base untuk membangun Conditional FP-tree
conditional_fp_tree_result = build_conditional_fp_tree(conditional_pattern_base_result)

# %%
# Tampilan hasil
print("\n5. Pembangkitan Conditional FP-tree:")
print(conditional_fp_tree_result)
# Out:
# 5. Pembangkitan Conditional FP-tree:
# {'Medan Jaya 2000': {'count': 0.0949845895208742, 'parent': {...}, 'children': {}}, 'Kerupuk Putih Jaring 2.000': {'count': 0.1263659288316055, 'parent': {...}, 'children': {'Medan Jaya 2000': {'count': 0.017091622303166153, 'parent': {...}, 'children': {}}}}, 'Roti Ikan Hiu Kacang': {'count': 0.17231717567946203, 'parent': {...}, 'children': {'Medan Jaya 2000': {'count': 0.017371812832726253, 'parent': {...}, 'children': {}}, 'Kerupuk Putih Jaring 2.000': {'count': 0.012608573830204538, 'parent': {...}, 'children': {}}, 'Pok-Pok Chicken': {'count': 0.011768002241524236, 'parent': {...}, 'children': {}}}}, 'Kerupuk Kuning': {'count': 0.18352479686186607, 'parent': {...}, 'children': {'Kerupuk Putih Jaring 2.000': {'count': 0.022135051835247967, 'parent': {...}, 'children': {}}, 'Medan Jaya 2000': {'count': 0.014569907537125245, 'parent': {...}, 'children': {}}, 'Kerupuk Kulit': {'count': 0.010647240123283833, 'parent': {...}, 'children': {}}}}, 'Pok-Pok Chicken': {'count': 0.10899411599887925, 'parent': {...}, 'children': {'Medan Jaya 2000': {'count': 0.017932193891846457, 'parent': {...}, 'children': {}}}}, 'Nabati Wafer Coklat 46 gr': {'count': 0.16195012608573828, 'parent': {...}, 'children': {'Nabati Wafer Keju 46 gr': {'count': 0.016531241244045952, 'parent': {...}, 'children': {}}, 'Roti Ikan Hiu Kacang': {'count': 0.015690669655365648, 'parent': {...}, 'children': {}}, 'Medan Jaya 2000': {'count': 0.015690669655365648, 'parent': {...}, 'children': {}}}}, 'HoHo Rasa Balado': {'count': 0.10479125805547773, 'parent': {...}, 'children': {'Medan Jaya 2000': {'count': 0.01288876435976464, 'parent': {...}, 'children': {}}, 'Pok-Pok Chicken': {'count': 0.011207621182404036, 'parent': {...}, 'children': {}}}}, 'Nabati Wafer Keju 46 gr': {'count': 0.07901372933594844, 'parent': {...}, 'children': {'Medan Jaya 2000': {'count': 0.01316895488932474, 'parent': {...}, 'children': {}}}}, 'Lotte Choco Pie Coklat': {'count': 0.04819277108433735, 'parent': {...}, 'children': {}}, 'Tricks Kimci': {'count': 0.07397029980386663, 'parent': {...}, 'children': {'Tricks Rendang': {'count': 0.013449145418884841, 'parent': {...}, 'children': {}}}}, 'Teh Botol Sosro 350ml': {'count': 0.04286915102269543, 'parent': {...}, 'children': {}}, 'AICE Chocolate Crispy': {'count': 0.04230876996357523, 'parent': {...}, 'children': {}}, 'Opak Padang': {'count': 0.04230876996357523, 'parent': {...}, 'children': {}}, 'Tricks Rendang': {'count': 0.04202857943401513, 'parent': {...}, 'children': {}}, 'Jetz Stick Choco Fiesta': {'count': 0.040347436256654524, 'parent': {...}, 'children': {}}, 'Beng Beng Reguler 20gr': {'count': 0.04006724572709443, 'parent': {...}, 'children': {}}, 'Kerupuk Tahu': {'count': 0.03950686466797422, 'parent': {...}, 'children': {}}, 'Roma Better vanilla 22gr': {'count': 0.039226674138414123, 'parent': {...}, 'children': {}}, 'Pucuk Harum 350ml': {'count': 0.03894648360885402, 'parent': {...}, 'children': {}}, 'Superstar Triple Chocolate 18 gr': {'count': 0.03894648360885402, 'parent': {...}, 'children': {}}, 'Fullo Blasto': {'count': 0.03670495937237321, 'parent': {...}, 'children': {}}, "Toretto's Potato Stick Balado 30gr": {'count': 0.03614457831325301, 'parent': {...}, 'children': {}}, 'Kerupuk Kulit': {'count': 0.035864387783692914, 'parent': {...}, 'children': {}}, 'Nextar Brownies': {'count': 0.034743625665452506, 'parent': {...}, 'children': {}}, 'Aneka Roti 2.500': {'count': 0.03446343513589241, 'parent': {...}, 'children': {}}, 'Borobudur 1000': {'count': 0.033622863547212105, 'parent': {...}, 'children': {}}, 'Toyaki Rasa Ayam Bawang 20gr': {'count': 0.033622863547212105, 'parent': {...}, 'children': {}}, 'Bakso Udang Bakar': {'count': 0.032502101428971704, 'parent': {...}, 'children': {}}, 'AICE Mochie Coklat': {'count': 0.0316615298402914, 'parent': {...}, 'children': {}}, 'AICE Taro Crispy': {'count': 0.030540767722050995, 'parent': {...}, 'children': {}}, 'Teh botol Sosro Kotak': {'count': 0.030540767722050995, 'parent':  ...

# %%
# Fungsi untuk pembangkitan Frequent Pattern
def generate_frequent_patterns(tree, min_support, prefix, frequent_patterns):
    for item, node in tree.items():
        new_prefix = prefix.copy()
        new_prefix.append(item)
        support = node['count']

        # Tambahkan ke frequent patterns jika support mencukupi
        if support >= min_support:
            frequent_patterns[tuple(new_prefix)] = support

        # Rekursif untuk anak-anak node
        generate_frequent_patterns(node['children'], min_support, new_prefix, frequent_patterns)

# %%
# Menggunakan Conditional FP-tree untuk pembangkitan Frequent Patterns
min_support_threshold = 0.01
frequent_patterns_result = {}
generate_frequent_patterns(conditional_fp_tree_result, min_support_threshold, [], frequent_patterns_result)

# %%
# Tampilan hasil
print("\n6. Pembangkitan Frequent Patterns:")
for pattern, support in frequent_patterns_result.items():
    print(f"{pattern}: {support}")
# Out:
# 6. Pembangkitan Frequent Patterns:
# ('Medan Jaya 2000',): 0.0949845895208742
# ('Kerupuk Putih Jaring 2.000',): 0.1263659288316055
# ('Kerupuk Putih Jaring 2.000', 'Medan Jaya 2000'): 0.017091622303166153
# ('Roti Ikan Hiu Kacang',): 0.17231717567946203
# ('Roti Ikan Hiu Kacang', 'Medan Jaya 2000'): 0.017371812832726253
# ('Roti Ikan Hiu Kacang', 'Kerupuk Putih Jaring 2.000'): 0.012608573830204538
# ('Roti Ikan Hiu Kacang', 'Pok-Pok Chicken'): 0.011768002241524236
# ('Kerupuk Kuning',): 0.18352479686186607
# ('Kerupuk Kuning', 'Kerupuk Putih Jaring 2.000'): 0.022135051835247967
# ('Kerupuk Kuning', 'Medan Jaya 2000'): 0.014569907537125245
# ('Kerupuk Kuning', 'Kerupuk Kulit'): 0.010647240123283833
# ('Pok-Pok Chicken',): 0.10899411599887925
# ('Pok-Pok Chicken', 'Medan Jaya 2000'): 0.017932193891846457
# ('Nabati Wafer Coklat 46 gr',): 0.16195012608573828
# ('Nabati Wafer Coklat 46 gr', 'Nabati Wafer Keju 46 gr'): 0.016531241244045952
# ('Nabati Wafer Coklat 46 gr', 'Roti Ikan Hiu Kacang'): 0.015690669655365648
# ('Nabati Wafer Coklat 46 gr', 'Medan Jaya 2000'): 0.015690669655365648
# ('HoHo Rasa Balado',): 0.10479125805547773
# ('HoHo Rasa Balado', 'Medan Jaya 2000'): 0.01288876435976464
# ('HoHo Rasa Balado', 'Pok-Pok Chicken'): 0.011207621182404036
# ('Nabati Wafer Keju 46 gr',): 0.07901372933594844
# ('Nabati Wafer Keju 46 gr', 'Medan Jaya 2000'): 0.01316895488932474
# ('Lotte Choco Pie Coklat',): 0.04819277108433735
# ('Tricks Kimci',): 0.07397029980386663
# ('Tricks Kimci', 'Tricks Rendang'): 0.013449145418884841
# ('Teh Botol Sosro 350ml',): 0.04286915102269543
# ('AICE Chocolate Crispy',): 0.04230876996357523
# ('Opak Padang',): 0.04230876996357523
# ('Tricks Rendang',): 0.04202857943401513
# ('Jetz Stick Choco Fiesta',): 0.040347436256654524
# ('Beng Beng Reguler 20gr',): 0.04006724572709443
# ('Kerupuk Tahu',): 0.03950686466797422
# ('Roma Better vanilla 22gr',): 0.039226674138414123
# ('Pucuk Harum 350ml',): 0.03894648360885402
# ('Superstar Triple Chocolate 18 gr',): 0.03894648360885402
# ('Fullo Blasto',): 0.03670495937237321
# ("Toretto's Potato Stick Balado 30gr",): 0.03614457831325301
# ('Kerupuk Kulit',): 0.035864387783692914
# ('Nextar Brownies',): 0.034743625665452506
# ('Aneka Roti 2.500',): 0.03446343513589241
# ('Borobudur 1000',): 0.033622863547212105
# ('Toyaki Rasa Ayam Bawang 20gr',): 0.033622863547212105
# ('Bakso Udang Bakar',): 0.032502101428971704
# ('AICE Mochie Coklat',): 0.0316615298402914
# ('AICE Taro Crispy',): 0.030540767722050995
# ('Teh botol Sosro Kotak',): 0.030540767722050995
# ('Yakult',): 0.030260577192490895
# ('Choki Choki Cashew Doraemon 10gr',): 0.02942000560381059
# ('AICE Mochie Klepon',): 0.02913981507425049
# ('Strawbeeri Crispy',): 0.02913981507425049
# ('Chitato Lite NOS Renceng',): 0.02885962454469039
# ('Nabati Siip chocolate',): 0.02885962454469039
# ('Kraft Keju Cake 16gr',): 0.02885962454469039
# ('Chiki Twist 22.5 gr',): 0.028299243485570186
# ('Vegetable Cheese Stick',): 0.027458671896889886
# ('Nabati Siip Corn',): 0.027178481367329786
# ('Tricks Original',): 0.07032782291958531
# ('Tricks Original', 'Tricks Rendang'): 0.011487811711964136
# ('Tricks Original', 'Tricks Kimci'): 0.010367049593723731
# ('AICE Mochie vanilla',): 0.02633790977864948
# ('Pisang Saleh',): 0.02549733818996918
# ('Toyaki Rasa BBQ',): 0.02549733818996918
# ('AICE Coffe Crispy',): 0.025217147660409077
# ('Baricho Chocolate Flavour 500',): 0.024656766601288876
# ('AICE Mochie Durian',): 0.023816195012608572
# ('Kerupuk Ubi 1.000',): 0.023536004483048472
# ('Good Time Chocochips Cookies',): 0.023536004483048472
# ('Garuda Atom Manis',): 0.023255813953488372
# ('Toyaki Rasa Jagung Bakar',): 0.02241524236480807
# ('Fruit tea Blackcurrent 350 ml',): 0.022135051835247967
# ('Toyaki Rasa Rumput Laut 20gr',): 0.022135051835247967
# ('Chocolate MAX Cone Corong',): 0.021854861305687867
# ('Oreo Chocolate Roll 133gr',): 0.021854861305687867
# ('Nabati Siip Keju',): 0.021574670776127767
# ('Bear Brand STM',): 0.021574670776127767
# ('Chitato Sapi Panggang',): 0.021294480246567667
# ('Timtam Maxi Vanilla 16gr',): 0.021294480246567667
# ('Gery Snack Cereal',): 0.021014289717007566
# ('Lotte Choco Pie Cheese',): 0.021014289717007566
# ('Roma Sari Gandum 2000',): 0.020734099187447463
# ('Astor Double Chocolate 40gr',): 0.020453908657887362
# ('Permen Karet 500 (1)',): 0.020173718128327262
# ('AICE 2 Colors Stick',): 0.020173718128327262
# ('Kerupuk Ubi Original Besar',): 0.019893527598767162
# ('AICE Sundae Strawberry',): 0.019613337069207062
# ('Oreo Softcake 16gr',): 0.019613337069207062
# ('Lotte Toppo Vanilla Chocolate',): 0.019613337069207062
# ('Tisu Sedang TESSA',): 0.01933314653964696
# ('Roma Arden Chocosplendid 30gr',): 0.018772765480526758
# ('Buavita Guava 250ml',): 0.018492574950966657
# ('Berry Choco MAX Strawberry',): 0.018492574950966657
# ('Garuda Rosta Rasa Pedas',): 0.017932193891846457
# ('Biskuat Bolu Coklat 6gr',): 0.017652003362286353
# ('Black Pandan',): 0.017371812832726253
# ('Fruit Tea Freeze Botol',): 0.017091622303166153
# ('Sweet Corn Stick',): 0.017091622303166153
# ('Oreo C/S/C Vanilla 133gr',): 0.016531241244045952
# ('Roma Malkist 2 Rasa Coklat dan Kelapa',): 0.016251050714485852
# ('Astor Singles 18gr',): 0.016251050714485852
# ('Black Chocolate',): 0.015970860184925748
# ('Kopiko 78C Coffee Latte 240ml',): 0.015970860184925748
# ('Gery Saluut Malkist Coklat Kelapa',): 0.015410479125805548
# ('Floridina Orange Botol 350ml',): 0.015410479125805548
# ('Oops Baked Chicken Tomato',): 0.015410479125805548
# ('Toyaki Rasa Bawang Pedas 20gr',): 0.015410479125805548
# ('Fruit tea Apel Botol',): 0.015410479125805548
# ('Sundae Coklat',): 0.015410479125805548
# ('Nextar Nastar',): 0.015130288596245448
# ('Choki Choki Stik 27gr',): 0.014850098066685346
# ('Permen Blaster Pop Hanger Manggo',): 0.014850098066685346
# ('Oreo Lup2000 Original 38gr',): 0.014850098066685346
# ('Wafer Tanggo Royal  Coklat 120 gr',): 0.014850098066685346
# ('Fruit Tea Blackcurrant Kotak',): 0.014289717007565145
# ('Roma Slai O Lai Strawberry 24gr',): 0.014009526478005043
# ('Permen Blaster Pop Hanger Grape',): 0.013729335948444943
# ('Kalpa 24gr',): 0.013449145418884841
# ('Oreo Lup2000 Ice Cream (Blueberry)',): 0.01316895488932474
# ('Canon Ball',): 0.01316895488932474
# ('Oops Roasted Sweet Corn',): 0.01316895488932474
# ('Hansaplast',): 0.01316895488932474
# ('Sabun Cream Ekonomi',): 0.012608573830204538
# ('Permen Blaster Pop Hanger Orange',): 0.012608573830204538
# ('Black Strawberry',): 0.012608573830204538
# ('White Koffie Renceng',): 0.012608573830204538
# ('Buavita Apel 250ml',): 0.012048192771084338
# ('Tanggo Wafer Royal Coklat 47 gr',): 0.012048192771084338
# ('Tanggo Wafer Vanilla Milk 47 gr',): 0.012048192771084338
# ('Roma Slai O Lai Blueberry 32gr',): 0.012048192771084338
# ('Buavita Mangga 250ml',): 0.012048192771084338
# ('Fruit tea Strawberry Botol',): 0.011768002241524236
# ('Hemaviton Jeruk',): 0.011487811711964136
# ('Toracafe Cappucino LJ 180ml',): 0.011487811711964136
# ('Permen Tamarin 500 (2)',): 0.011207621182404036
# ('Garuda Rosta Rasa Bawang',): 0.010927430652843934
# ('Hemaviton Less Sugar',): 0.010927430652843934
# ('Permen Kis 500 (2)',): 0.010927430652843934
# ('Roma Slai O Lai Strawberry Roll',): 0.010647240123283833
# ('Roma Slai O Lai Blueberry Roll 128Gram',): 0.010367049593723731
# ('Kerupuk Udang 3.000',): 0.010086859064163631
# ('Kopi Luwak White Ori Botol',): 0.010086859064163631
# ('Dark Coklat',): 0.010086859064163631

# %%
# Fungsi untuk menghasilkan Frequent 2-itemsets
def generate_frequent_2_itemsets(tree, min_support, frequent_2_itemsets):
    # Iterasi melalui setiap item pada Conditional FP-tree
    for item, node in tree.items():
        support_item = node['count']
        # Cek apakah item tersebut memenuhi syarat support
        if support_item >= min_support:
            # Jika memenuhi, iterasi lagi untuk mencari item yang memiliki support cukup
            for child_item, child_node in node['children'].items():
                support_2_itemset = child_node['count']
                # Cek apakah pasangan item memenuhi syarat support
                if support_2_itemset >= min_support:
                    # Tambahkan ke frequent 2-itemsets
                    frequent_2_itemsets[(item, child_item)] = support_2_itemset

# %%
# Menggunakan fungsi untuk menghasilkan Frequent 2-itemsets
min_support_2_itemsets = 0.01
frequent_2_itemsets_result = {}
generate_frequent_2_itemsets(conditional_fp_tree_result, min_support_2_itemsets, frequent_2_itemsets_result)

# %%
# Tampilan hasil Frequent 2-itemsets
print("\n7. Pembangkitan Frequent 2-itemsets:")
for itemset, support in frequent_2_itemsets_result.items():
    print(f"{itemset}: {support}")
# Out:
# 7. Pembangkitan Frequent 2-itemsets:
# ('Kerupuk Putih Jaring 2.000', 'Medan Jaya 2000'): 0.017091622303166153
# ('Roti Ikan Hiu Kacang', 'Medan Jaya 2000'): 0.017371812832726253
# ('Roti Ikan Hiu Kacang', 'Kerupuk Putih Jaring 2.000'): 0.012608573830204538
# ('Roti Ikan Hiu Kacang', 'Pok-Pok Chicken'): 0.011768002241524236
# ('Kerupuk Kuning', 'Kerupuk Putih Jaring 2.000'): 0.022135051835247967
# ('Kerupuk Kuning', 'Medan Jaya 2000'): 0.014569907537125245
# ('Kerupuk Kuning', 'Kerupuk Kulit'): 0.010647240123283833
# ('Pok-Pok Chicken', 'Medan Jaya 2000'): 0.017932193891846457
# ('Nabati Wafer Coklat 46 gr', 'Nabati Wafer Keju 46 gr'): 0.016531241244045952
# ('Nabati Wafer Coklat 46 gr', 'Roti Ikan Hiu Kacang'): 0.015690669655365648
# ('Nabati Wafer Coklat 46 gr', 'Medan Jaya 2000'): 0.015690669655365648
# ('HoHo Rasa Balado', 'Medan Jaya 2000'): 0.01288876435976464
# ('HoHo Rasa Balado', 'Pok-Pok Chicken'): 0.011207621182404036
# ('Nabati Wafer Keju 46 gr', 'Medan Jaya 2000'): 0.01316895488932474
# ('Tricks Kimci', 'Tricks Rendang'): 0.013449145418884841
# ('Tricks Original', 'Tricks Rendang'): 0.011487811711964136
# ('Tricks Original', 'Tricks Kimci'): 0.010367049593723731

# %%
# Mencari Support 2 Itemset
support_2_itemset_result = {}
total_transactions = len(transactions)

for itemset, support in frequent_2_itemsets_result.items():
    support_2_itemset_result[itemset] = support / total_transactions

# %%
# Tampilan hasil Support 2 Itemset
print("\n8. Mencari Support 2 Itemset:")
for itemset, support in support_2_itemset_result.items():
    print(f"{itemset}: {support}")
# Out:
# 8. Mencari Support 2 Itemset:
# ('Kerupuk Putih Jaring 2.000', 'Medan Jaya 2000'): 4.788910704165355e-06
# ('Roti Ikan Hiu Kacang', 'Medan Jaya 2000'): 4.867417437020525e-06
# ('Roti Ikan Hiu Kacang', 'Kerupuk Putih Jaring 2.000'): 3.532802978482639e-06
# ('Roti Ikan Hiu Kacang', 'Pok-Pok Chicken'): 3.2972827799171297e-06
# ('Kerupuk Kuning', 'Kerupuk Putih Jaring 2.000'): 6.202031895558411e-06
# ('Kerupuk Kuning', 'Medan Jaya 2000'): 4.082350108468828e-06
# ('Kerupuk Kuning', 'Kerupuk Kulit'): 2.983255848496451e-06
# ('Pok-Pok Chicken', 'Medan Jaya 2000'): 5.024430902730865e-06
# ('Nabati Wafer Coklat 46 gr', 'Nabati Wafer Keju 46 gr'): 4.631897238455016e-06
# ('Nabati Wafer Coklat 46 gr', 'Roti Ikan Hiu Kacang'): 4.396377039889506e-06
# ('Nabati Wafer Coklat 46 gr', 'Medan Jaya 2000'): 4.396377039889506e-06
# ('HoHo Rasa Balado', 'Medan Jaya 2000'): 3.611309711337809e-06
# ('HoHo Rasa Balado', 'Pok-Pok Chicken'): 3.1402693142067905e-06
# ('Nabati Wafer Keju 46 gr', 'Medan Jaya 2000'): 3.6898164441929784e-06
# ('Tricks Kimci', 'Tricks Rendang'): 3.768323177048148e-06
# ('Tricks Original', 'Tricks Rendang'): 3.21877604706196e-06
# ('Tricks Original', 'Tricks Kimci'): 2.904749115641281e-06

# %%
# Mencari Confidence 2 Itemset
confidence_2_itemset_result = {}

for itemset, support in frequent_2_itemsets_result.items():
    item_A, item_B = itemset
    support_A = frequent_patterns_result.get((item_A,), 0)
    confidence = support / support_A
    confidence_2_itemset_result[itemset] = confidence

# %%
# Tampilan hasil Confidence 2 Itemset
print("\n9. Mencari Confidence 2 Itemset:")
for itemset, confidence in confidence_2_itemset_result.items():
    print(f"{itemset}: {confidence}")
# Out:
# 9. Mencari Confidence 2 Itemset:
# ('Kerupuk Putih Jaring 2.000', 'Medan Jaya 2000'): 0.1352549889135255
# ('Roti Ikan Hiu Kacang', 'Medan Jaya 2000'): 0.1008130081300813
# ('Roti Ikan Hiu Kacang', 'Kerupuk Putih Jaring 2.000'): 0.07317073170731707
# ('Roti Ikan Hiu Kacang', 'Pok-Pok Chicken'): 0.06829268292682927
# ('Kerupuk Kuning', 'Kerupuk Putih Jaring 2.000'): 0.12061068702290076
# ('Kerupuk Kuning', 'Medan Jaya 2000'): 0.07938931297709924
# ('Kerupuk Kuning', 'Kerupuk Kulit'): 0.058015267175572524
# ('Pok-Pok Chicken', 'Medan Jaya 2000'): 0.16452442159383032
# ('Nabati Wafer Coklat 46 gr', 'Nabati Wafer Keju 46 gr'): 0.10207612456747407
# ('Nabati Wafer Coklat 46 gr', 'Roti Ikan Hiu Kacang'): 0.09688581314878894
# ('Nabati Wafer Coklat 46 gr', 'Medan Jaya 2000'): 0.09688581314878894
# ('HoHo Rasa Balado', 'Medan Jaya 2000'): 0.1229946524064171
# ('HoHo Rasa Balado', 'Pok-Pok Chicken'): 0.10695187165775401
# ('Nabati Wafer Keju 46 gr', 'Medan Jaya 2000'): 0.16666666666666669
# ('Tricks Kimci', 'Tricks Rendang'): 0.1818181818181818
# ('Tricks Original', 'Tricks Rendang'): 0.16334661354581675
# ('Tricks Original', 'Tricks Kimci'): 0.14741035856573706

# %%
# Langkah 5: Evaluasi
# Evaluasi kualitas aturan asosiasi dapat dilakukan dengan menghitung metrik seperti confidence, lift, dan support.
# Fungsi untuk menghitung lift
def calculate_lift(itemset, support_AB, support_A, support_B):
    return support_AB / (support_A * support_B)

# %%
# Fungsi untuk mengevaluasi kualitas aturan asosiasi
def evaluate_association_rules(association_rules, frequent_patterns):
    evaluation_results = {}
    for itemset, support_AB in association_rules.items():
        item_A, item_B = itemset
        support_A = frequent_patterns.get((item_A,), 0)
        support_B = frequent_patterns.get((item_B,), 0)
        confidence = support_AB / support_A
        lift = calculate_lift(itemset, support_AB, support_A, support_B)
        evaluation_results[itemset] = {'support_AB': support_AB, 'support_A': support_A, 'support_B': support_B, 'confidence': confidence, 'lift': lift}
    return evaluation_results

# %%
# Evaluasi aturan asosiasi
evaluation_results = evaluate_association_rules(frequent_2_itemsets_result, frequent_patterns_result)

# %%
# Tampilkan hasil evaluasi
print("\n10. Evaluasi Aturan Asosiasi:")
for itemset, metrics in evaluation_results.items():
    print(f"{itemset}: {metrics}")
# Out:
# 10. Evaluasi Aturan Asosiasi:
# ('Kerupuk Putih Jaring 2.000', 'Medan Jaya 2000'): {'support_AB': 0.017091622303166153, 'support_A': 0.1263659288316055, 'support_B': 0.0949845895208742, 'confidence': 0.1352549889135255, 'lift': 1.4239677151397416}
# ('Roti Ikan Hiu Kacang', 'Medan Jaya 2000'): {'support_AB': 0.017371812832726253, 'support_A': 0.17231717567946203, 'support_B': 0.0949845895208742, 'confidence': 0.1008130081300813, 'lift': 1.0613617286615344}
# ('Roti Ikan Hiu Kacang', 'Kerupuk Putih Jaring 2.000'): {'support_AB': 0.012608573830204538, 'support_A': 0.17231717567946203, 'support_B': 0.1263659288316055, 'confidence': 0.07317073170731707, 'lift': 0.5790384511383916}
# ('Roti Ikan Hiu Kacang', 'Pok-Pok Chicken'): {'support_AB': 0.011768002241524236, 'support_A': 0.17231717567946203, 'support_B': 0.10899411599887925, 'confidence': 0.06829268292682927, 'lift': 0.6265721988839424}
# ('Kerupuk Kuning', 'Kerupuk Putih Jaring 2.000'): {'support_AB': 0.022135051835247967, 'support_A': 0.18352479686186607, 'support_B': 0.1263659288316055, 'confidence': 0.12061068702290076, 'lift': 0.9544557471945294}
# ('Kerupuk Kuning', 'Medan Jaya 2000'): {'support_AB': 0.014569907537125245, 'support_A': 0.18352479686186607, 'support_B': 0.0949845895208742, 'confidence': 0.07938931297709924, 'lift': 0.8358125605170122}
# ('Kerupuk Kuning', 'Kerupuk Kulit'): {'support_AB': 0.010647240123283833, 'support_A': 0.18352479686186607, 'support_B': 0.035864387783692914, 'confidence': 0.058015267175572524, 'lift': 1.6176288167938933}
# ('Pok-Pok Chicken', 'Medan Jaya 2000'): {'support_AB': 0.017932193891846457, 'support_A': 0.10899411599887925, 'support_B': 0.0949845895208742, 'confidence': 0.16452442159383032, 'lift': 1.7321169931220661}
# ('Nabati Wafer Coklat 46 gr', 'Nabati Wafer Keju 46 gr'): {'support_AB': 0.016531241244045952, 'support_A': 0.16195012608573828, 'support_B': 0.07901372933594844, 'confidence': 0.10207612456747407, 'lift': 1.2918783283025352}
# ('Nabati Wafer Coklat 46 gr', 'Roti Ikan Hiu Kacang'): {'support_AB': 0.015690669655365648, 'support_A': 0.16195012608573828, 'support_B': 0.17231717567946203, 'confidence': 0.09688581314878894, 'lift': 0.5622527920780939}
# ('Nabati Wafer Coklat 46 gr', 'Medan Jaya 2000'): {'support_AB': 0.015690669655365648, 'support_A': 0.16195012608573828, 'support_B': 0.0949845895208742, 'confidence': 0.09688581314878894, 'lift': 1.0200161272213206}
# ('HoHo Rasa Balado', 'Medan Jaya 2000'): {'support_AB': 0.01288876435976464, 'support_A': 0.10479125805547773, 'support_B': 0.0949845895208742, 'confidence': 0.1229946524064171, 'lift': 1.2948906030634297}
# ('HoHo Rasa Balado', 'Pok-Pok Chicken'): {'support_AB': 0.011207621182404036, 'support_A': 0.10479125805547773, 'support_B': 0.10899411599887925, 'confidence': 0.10695187165775401, 'lift': 0.981262801919085}
# ('Nabati Wafer Keju 46 gr', 'Medan Jaya 2000'): {'support_AB': 0.01316895488932474, 'support_A': 0.07901372933594844, 'support_B': 0.0949845895208742, 'confidence': 0.16666666666666669, 'lift': 1.7546705998033432}
# ('Tricks Kimci', 'Tricks Rendang'): {'support_AB': 0.013449145418884841, 'support_A': 0.07397029980386663, 'support_B': 0.04202857943401513, 'confidence': 0.1818181818181818, 'lift': 4.326060606060605}
# ('Tricks Original', 'Tricks Rendang'): {'support_AB': 0.011487811711964136, 'support_A': 0.07032782291958531, 'support_B': 0.04202857943401513, 'confidence': 0.16334661354581675, 'lift': 3.8865604249668}
# ('Tricks Original', 'Tricks Kimci'): {'support_AB': 0.010367049593723731, 'support_A': 0.07032782291958531, 'support_B': 0.07397029980386663, 'confidence': 0.14741035856573706, 'lift': 1.9928317034890741}

# %%
# Simpan model menggunakan pickle
with open('Model.pkl', 'wb') as model_file:
    pickle.dump(frequent_patterns_result, model_file)
